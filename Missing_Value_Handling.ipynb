# %%
#import need libraries
import pandas as pd # Pandas support to load files with different file format.
import numpy as np # Numpy reveals the mathemetical representation of the object.

# %%
# data onboarding
from google.colab import files
dataset = files.upload()
# Out:
#      <input type="file" id="files-ca229d0c-41f5-4740-8de2-684387cca26b" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-ca229d0c-41f5-4740-8de2-684387cca26b">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# dataframe
data_frame = pd.read_csv('oil-company-doe (1).csv')
data_frame
# Out:
#       x1    x2   x3    x4      y
# 0   4.38  1.60   No  2.18  28.03
# 1   6.20  2.26  NaN  2.18  37.25
# 2   6.20  2.26  Yes  2.18  37.22
# 3    NaN  2.26  Yes  3.08  37.06
# 4   6.20  1.60  NaN  3.08  39.23
# 5   6.20  1.60   No  3.08  30.86
# 6   6.20  1.60   No  3.08    NaN
# 7   6.20  1.60  Yes  3.08  39.21
# 8   4.38  2.26   No  3.08  29.31
# 9   4.38  2.26  Yes  3.08  37.03
# 10  4.38   NaN   No  3.08    NaN
# 11  6.20  2.26   No   NaN  34.63
# 12  5.60  2.26   No  2.78  29.73
# 13  6.20  1.82  Yes  2.48  37.89
# 14  6.20  2.04   No  2.18  31.71
# 15  5.60  1.60   No  2.18  29.00
# 16  4.98  1.60  Yes   NaN  36.15
# 17  5.60  2.26   No  2.78  29.77
# 18   NaN  2.04   No  2.18  29.40

# %%
# shallow copy
df = data_frame.copy()

# %%
df
# Out:
#       x1    x2   x3    x4      y
# 0   4.38  1.60   No  2.18  28.03
# 1   6.20  2.26  NaN  2.18  37.25
# 2   6.20  2.26  Yes  2.18  37.22
# 3    NaN  2.26  Yes  3.08  37.06
# 4   6.20  1.60  NaN  3.08  39.23
# 5   6.20  1.60   No  3.08  30.86
# 6   6.20  1.60   No  3.08    NaN
# 7   6.20  1.60  Yes  3.08  39.21
# 8   4.38  2.26   No  3.08  29.31
# 9   4.38  2.26  Yes  3.08  37.03
# 10  4.38   NaN   No  3.08    NaN
# 11  6.20  2.26   No   NaN  34.63
# 12  5.60  2.26   No  2.78  29.73
# 13  6.20  1.82  Yes  2.48  37.89
# 14  6.20  2.04   No  2.18  31.71
# 15  5.60  1.60   No  2.18  29.00
# 16  4.98  1.60  Yes   NaN  36.15
# 17  5.60  2.26   No  2.78  29.77
# 18   NaN  2.04   No  2.18  29.40

# %%
df.shape
# Out:
# (19, 5)

# %%
df.columns
# Out:
# Index(['x1', 'x2', 'x3', 'x4', 'y'], dtype='object')

# %%
df.head()
# Out:
#      x1    x2   x3    x4      y
# 0  4.38  1.60   No  2.18  28.03
# 1  6.20  2.26  NaN  2.18  37.25
# 2  6.20  2.26  Yes  2.18  37.22
# 3   NaN  2.26  Yes  3.08  37.06
# 4  6.20  1.60  NaN  3.08  39.23

# %%
df.tail()
# Out:
#       x1    x2   x3    x4      y
# 14  6.20  2.04   No  2.18  31.71
# 15  5.60  1.60   No  2.18  29.00
# 16  4.98  1.60  Yes   NaN  36.15
# 17  5.60  2.26   No  2.78  29.77
# 18   NaN  2.04   No  2.18  29.40

# %%
# It will display the use needed record.
df.iloc[7:12]
# Out:
#       x1    x2   x3    x4      y
# 7   6.20  1.60  Yes  3.08  39.21
# 8   4.38  2.26   No  3.08  29.31
# 9   4.38  2.26  Yes  3.08  37.03
# 10  4.38   NaN   No  3.08    NaN
# 11  6.20  2.26   No   NaN  34.63

# %%
# Technical enquiry of the dataframe(check the data type for each and every column).
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19 entries, 0 to 18
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   x1      17 non-null     float64
#  1   x2      18 non-null     float64
#  2   x3      17 non-null     object
#  3   x4      17 non-null     float64
#  4   y       17 non-null     float64
# dtypes: float64(4), object(1)
# memory usage: 888.0+ bytes

# %%
# Mini Statistical report.
df.describe()
# Out:
#               x1         x2         x4          y
# count  17.000000  18.000000  17.000000  17.000000
# mean    5.594118   1.954444   2.691765  33.734118
# std     0.773685   0.312395   0.421133   4.092284
# min     4.380000   1.600000   2.180000  28.030000
# 25%     4.980000   1.600000   2.180000  29.730000
# 50%     6.200000   2.040000   2.780000  34.630000
# 75%     6.200000   2.260000   3.080000  37.220000
# max     6.200000   2.260000   3.080000  39.230000

# %%
# it will identify the null value of the column.
df.isnull().sum()
# Out:
# x1    0
# x2    0
# x3    0
# x4    0
# y     0
# dtype: int64

# %% [markdown]
# **MISSING VALUE HANDALING:**
#
# *   If our dataset have four independent variable and one dependent variable all features are have missing values.We must handling the missing values.

# %%
# # If we have missing values in the target column/dependent variable.We must drop the record.
df = df.dropna(subset=['y'])

# %%
## If we have missing values in the independent variable.We must handle the data.
# Replace the missing values in the categorical column by using mode values. mode value means repeated values.
col = ['x3']
df[col] = df[col].fillna(df.mode().iloc[0])

# %%
# # Replace the missing values in the categorical column by using mean,median,mode values.
col = ['x1','x2','x4']
df[col] = df[col].fillna(df.mean())
# Out:
# <ipython-input-33-7cc469716aab>:2: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df[col] = df[col].fillna(df.mean())
# <ipython-input-33-7cc469716aab>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col] = df[col].fillna(df.mean())

# %%
# it will identify the null value of the column
df.isnull().sum()
# Out:
# x1    0
# x2    0
# x3    0
# x4    0
# y     0
# dtype: int64
